# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cleaned_data.csv')
df
# Out:
#              Job Title               Salary Estimate  \
# 0    Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1       Data Scientist  $137K-$171K (Glassdoor est.)
# 2       Data Scientist  $137K-$171K (Glassdoor est.)
# 3       Data Scientist  $137K-$171K (Glassdoor est.)
# 4       Data Scientist  $137K-$171K (Glassdoor est.)
# ..                 ...                           ...
# 667     Data Scientist  $105K-$167K (Glassdoor est.)
# 668     Data Scientist  $105K-$167K (Glassdoor est.)
# 669     Data Scientist  $105K-$167K (Glassdoor est.)
# 670     Data Scientist  $105K-$167K (Glassdoor est.)
# 671     Data Scientist  $105K-$167K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# ...

# %%
df.head()
# Out:
#            Job Title               Salary Estimate  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8     Boston, MA              Boston, MA
# ...

# %% [markdown]
# # job title simplefier

# %%
def title(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
            return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    if 'manager' in title.lower():
        return 'manager'
    if 'director' in title.lower():
        return 'director'
    else:
        return 'na'
def seniority(title):
    if 'senior' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower() or 'sr.' in title.lower() or 'sr' in title.lower():
        return 'sr'
    elif 'junior' in title.lower() or 'jr.' in title.lower() or 'jr' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
df['job_simp'] = df['Job Title'].apply(title)
df.job_simp.value_counts()
# Out:
# data scientist    455
# na                 69
# analyst            55
# data engineer      47
# mle                36
# manager             7
# director            3
# Name: job_simp, dtype: int64

# %%
df['senority'] = df['Job Title'].apply(seniority)
df.senority.value_counts()
# Out:
# na    576
# sr     94
# jr      2
# Name: senority, dtype: int64

# %% [markdown]
# # fix states

# %%
df.job_state.value_counts()
# Out:
#  CA              165
#  VA               89
#  MA               62
#  NY               52
#  MD               40
#  IL               30
#  DC               26
#  TX               17
#  WA               16
#  OH               14
#  PA               12
#  MO               12
# United States     11
#  NJ               10
#  CO               10
#  GA                9
#  NC                9
#  TN                8
#  FL                8
# Remote             6
#  OK                6
#  WI                6
#  IN                5
#  MI                5
#  AL                4
#  CT                4
#  MN                4
#  AZ                4
#  NE                3
#  UT                3
#  IA                3
#  RI                2
# New Jersey         2
#  SC                2
#  OR                2
# Utah               2
#  NH                2
#  MS                1
#  LA                1
#  KS                1
# Texas              1
#  DE                1
# California         1
# ...

# %%
df['job_state']=df.job_state.apply(lambda x : 'CA' if x.strip().lower()=='california' or x.strip().lower()=='united states' or x.strip().lower()=='remote'  or x.strip().lower()=='utah' or x.strip().lower()=='new jersey' or x.strip().lower()=='texas' else x.strip())
df.job_state.value_counts()
# Out:
# CA    188
# VA     89
# MA     62
# NY     52
# MD     40
# IL     30
# DC     26
# TX     17
# WA     16
# OH     14
# MO     12
# PA     12
# NJ     10
# CO     10
# NC      9
# GA      9
# TN      8
# FL      8
# OK      6
# WI      6
# IN      5
# MI      5
# CT      4
# AZ      4
# AL      4
# MN      4
# NE      3
# UT      3
# IA      3
# OR      2
# SC      2
# RI      2
# NH      2
# DE      1
# LA      1
# MS      1
# KS      1
# WV      1
# Name: job_state, dtype: int64

# %% [markdown]
# # job description length

# %%
df
# Out:
#              Job Title               Salary Estimate  \
# 0    Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1       Data Scientist  $137K-$171K (Glassdoor est.)
# 2       Data Scientist  $137K-$171K (Glassdoor est.)
# 3       Data Scientist  $137K-$171K (Glassdoor est.)
# 4       Data Scientist  $137K-$171K (Glassdoor est.)
# ..                 ...                           ...
# 667     Data Scientist  $105K-$167K (Glassdoor est.)
# 668     Data Scientist  $105K-$167K (Glassdoor est.)
# 669     Data Scientist  $105K-$167K (Glassdoor est.)
# 670     Data Scientist  $105K-$167K (Glassdoor est.)
# 671     Data Scientist  $105K-$167K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# ...

# %%
df['desc_len'] = df['Job Description'].apply(lambda x : len(x))
df['desc_len']
# Out:
# 0      3389
# 1      4076
# 2      8749
# 3      3349
# 4      2728
#        ...
# 667    3653
# 668    1251
# 669    2793
# 670    3426
# 671    3000
# Name: desc_len, Length: 672, dtype: int64

# %% [markdown]
# # competetor length

# %%
df['no_of_Competitors']=df.Competitors.apply(lambda x: len(x.split(',')) if x!='-1' else 0)
df['no_of_Competitors']
# Out:
# 0      3
# 1      0
# 2      0
# 3      3
# 4      3
#       ..
# 667    0
# 668    0
# 669    0
# 670    0
# 671    0
# Name: no_of_Competitors, Length: 672, dtype: int64

# %%
df
# Out:
#              Job Title               Salary Estimate  \
# 0    Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1       Data Scientist  $137K-$171K (Glassdoor est.)
# 2       Data Scientist  $137K-$171K (Glassdoor est.)
# 3       Data Scientist  $137K-$171K (Glassdoor est.)
# 4       Data Scientist  $137K-$171K (Glassdoor est.)
# ..                 ...                           ...
# 667     Data Scientist  $105K-$167K (Glassdoor est.)
# 668     Data Scientist  $105K-$167K (Glassdoor est.)
# 669     Data Scientist  $105K-$167K (Glassdoor est.)
# 670     Data Scientist  $105K-$167K (Glassdoor est.)
# 671     Data Scientist  $105K-$167K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# ...

# %% [markdown]
# # hourly wages amount

# %%
df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly ==1 else x.min_salary, axis =1)
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly ==1 else x.max_salary, axis =1)

# %%
df[df.hourly==1][['hourly','min_salary','max_salary']]
# Out:
#      hourly  min_salary  max_salary
# 4         1         274         342
# 67        1         158         262
# 156       1         202         330

# %%
df.company_txt
# Out:
# 0               Healthfirst
# 1                   ManTech
# 2            Analysis Group
# 3                   INFICON
# 4        Affinity Solutions
#                ...
# 667                TRANZACT
# 668                    JKGT
# 669              AccessHope
# 670    ChaTeck Incorporated
# 671           1-800-Flowers
# Name: company_txt, Length: 672, dtype: object

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employer_provided_salary  \
# count  672.000000   672.000000  672.000000                     672.0
# mean     3.518601  1635.529762    0.004464                       0.0
# std      1.410329   756.746640    0.066716                       0.0
# min     -1.000000    -1.000000    0.000000                       0.0
# 25%      3.300000  1917.750000    0.000000                       0.0
# 50%      3.800000  1995.000000    0.000000                       0.0
# 75%      4.300000  2009.000000    0.000000                       0.0
# max      5.000000  2019.000000    1.000000                       0.0
#
#        min salary  max salary  min_salary  max_salary  avg_salary         age  \
# count  672.000000  672.000000  672.000000  672.000000  672.000000  672.000000
# mean    99.196429  148.130952   99.668155  148.825893  123.663690   32.714286
# std     33.009958   48.035110   33.957829   49.293800   39.580268   40.056688
# ...

# %%
df.min_salary.hist()
df.max_salary.hist()
# Out:
# <AxesSubplot: >

# %%
[x for x in df.columns]
# Out:
# ['Job Title',
#  'Salary Estimate',
#  'Job Description',
#  'Rating',
#  'Company Name',
#  'Location',
#  'Headquarters',
#  'Size',
#  'Founded',
#  'Type of ownership',
#  'Industry',
#  'Sector',
#  'Revenue',
#  'Competitors',
#  'hourly',
#  'employer_provided_salary',
#  'min salary',
#  'max salary',
#  'min_salary',
#  'max_salary',
#  'avg_salary',
#  'company_txt',
#  'job_state',
#  'age',
#  'same_state',
#  'python',
#  'rstudio',
#  'spark',
#  'aws',
#  'excel',
#  'job_simp',
#  'senority',
#  'desc_len',
#  'no_of_Competitors']

# %%
df.boxplot(column=['desc_len','age','Rating','avg_salary'])
# Out:
# <AxesSubplot: >

# %%
df[['desc_len','age','Rating','avg_salary']].corr()
# Out:
#             desc_len       age    Rating  avg_salary
# desc_len    1.000000  0.252212 -0.011147    0.002298
# age         0.252212  1.000000  0.141791   -0.048532
# Rating     -0.011147  0.141791  1.000000   -0.071066
# avg_salary  0.002298 -0.048532 -0.071066    1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age','avg_salary','Rating','desc_len','no_of_Competitors']].corr(),vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot: >

# %% [markdown]
# #  cd "D:\Download D\vs code work space\datascience\kenjee\ds_salary_proj"

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided_salary', 'min salary', 'max salary',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'job_state',
#        'age', 'same_state', 'python', 'rstudio', 'spark', 'aws', 'excel',
#        'job_simp', 'senority', 'desc_len', 'no_of_Competitors'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_txt', 'job_state','same_state', 'python', 'rstudio',
       'spark', 'aws', 'excel', 'job_simp', 'senority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 207
# graph for Headquarters: total = 229
# graph for Size: total = 9
# graph for Type of ownership: total = 13
# graph for Industry: total = 58
# graph for Sector: total = 23
# graph for Revenue: total = 14
# graph for company_txt: total = 432
# graph for job_state: total = 38
# graph for same_state: total = 2
# graph for python: total = 2
# graph for rstudio: total = 2
# graph for spark: total = 2
# graph for aws: total = 2
# graph for excel: total = 2
# graph for job_simp: total = 7
# graph for senority: total = 3

# %%
for i in df_cat[['Location','Headquarters','Industry','company_txt']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for Headquarters: total = 20
# graph for Industry: total = 20
# graph for company_txt: total = 20

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided_salary', 'min salary', 'max salary',
#        'min_salary', 'max_salary', 'avg_salary', 'company_txt', 'job_state',
#        'age', 'same_state', 'python', 'rstudio', 'spark', 'aws', 'excel',
#        'job_simp', 'senority', 'desc_len', 'no_of_Competitors'],
#       dtype='object')

# %%
pd.pivot_table(df,index='job_simp',values='avg_salary')
# Out:
#                 avg_salary
# job_simp
# analyst         115.718182
# data engineer   113.808511
# data scientist  125.216484
# director        127.333333
# manager         138.214286
# mle             117.236111
# na              128.188406

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df,index=['job_simp','company_txt','job_state','senority'],values='max_salary').sort_values('max_salary',ascending=False)
# Out:
#                                                                                       max_salary
# job_simp       company_txt                                        job_state senority
# data scientist Affinity Solutions                                 NY        na        342.000000
# na             Southwest Research Institute                       OH        na        331.000000
# data scientist Aptive                                             DC        na        331.000000
#                Alaka`ina Foundation Family of Companies           TX        na        331.000000
#                CompuForce                                         NY        na        331.000000
#                Creative Circle                                    CA        na        331.000000
#                Roche                                              CA        sr        331.000000
#                AstraZeneca                                        DE        na        331.000000
# ...

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
df.to_csv('eda.csv')
